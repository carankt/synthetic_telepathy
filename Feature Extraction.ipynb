# %%
from dataloader import get_loader
root = '/Volumes/Datasets/inner_speech/derivatives/'
# root =  'dataset/derivatives/' # -sil
creater = get_loader(root, channel_list= ["A4", "A5", "A19", "A20", "A32"], n_sess= 3)
xn, yn = creater.load_multiple_subjects([1, 2, 4, 5, 6, 7])

# %%
xn.shape
# Out:
# (1376, 5, 1153)

# %%
raw_file = "/Volumes/Datasets/inner_speech/sub-01/ses-01/eeg/sub-01_ses-01_task-innerspeech_eeg.bdf"

# %%
a26.get_data().shape
# Out:
# (1, 115712)

# %%
import mne
X= mne.read_epochs("/Volumes/Datasets/inner_speech/derivatives/sub-01/ses-01/sub-01_ses-01_eeg-epo.fif",verbose='WARNING')
a12 = X.pick_channels(ch_names = ["A12", "A26"])
#a26 = X.pick_channels(ch_names = ["A26"])

# %%
a12.get_data().shape
# Out:
# (200, 2, 1153)

# %%
a12_1 = a12.get_data()
a26_1 = a26.get_data()

# %%
import matplotlib.pyplot as plt
plt.plot(xn[1, 0, :])

# %%
plt.plot(xn[1, 1, :])
